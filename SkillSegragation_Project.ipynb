# %%
# %matplotlib inline
from nltk.corpus import stopwords
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection and Preprocessing

# %%
skill_data = pd.read_csv('Raw_Skills_Dataset.csv')

# %%
skill_data.head()
# Out:
#           RAW DATA
# 0         What ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          Lambdas

# %%
skill_data
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
skill_data.shape
# Out:
# (34116, 1)

# %%
skill_data.describe()
# Out:
#        RAW DATA
# count     34116
# unique    15677
# top      Python
# freq        272

# %% [markdown]
# # Checking for NULLs and removing them

# %%
skill_data.isnull().sum()
# Out:
# RAW DATA    0
# dtype: int64

# %%
skill_data = skill_data.fillna('')

# %%
skill_data.isnull().sum()
# Out:
# RAW DATA    0
# dtype: int64

# %% [markdown]
# # Droppping duplicates from data

# %%
skill_data.shape
# Out:
# (34116, 1)

# %%
skill_data.drop_duplicates(inplace=True)

# %%
skill_data.shape
# Out:
# (15677, 1)

# %%
df= skill_data.to_string()

# %%
print(df)
# Out:
#                                                                                                                        RAW DATA
# 0                                                                                                                      What ifs
# 1                                                                                                                     seniority
# 2                                                                                                                   familiarity
# 3                                                                                                               functionalities
# 4                                                                                                                       Lambdas
# 5                                                                                                                  Java Streams
# ...

# %% [markdown]
# # PreProcessing and Data Cleaning

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\A\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
special_character_remover = re.compile('[/(){}\[\]\|@,;]')
extra_symbol_remover = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

# %%
def clean_text(text):
    text = text.lower()
    text = special_character_remover.sub(' ', text)
    text = extra_symbol_remover.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    return text
    
df = df.apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17120/1046147180.py in <module>
#       6     return text
#       7
# ----> 8 df = df.apply(clean_text)
#
# AttributeError: 'str' object has no attribute 'apply'

# %% [markdown]
# # Train-Test Splitting

# %%
from sklearn.model_selection import train_test_split
X = skill_data
y = ['HardSkill','SoftSkill']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17120/2859131691.py in <module>
#       2 X = skill_data
#       3 y = ['HardSkill','SoftSkill']
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)
#
# c:\users\a\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2417         raise ValueError("At least one array required as input")
#    2418
# -> 2419     arrays = indexable(*arrays)
#    2420
#    2421     n_samples = _num_samples(arrays[0])
#
# c:\users\a\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     368     """
#     369     result = [_make_indexable(X) for X in iterables]
# ...
